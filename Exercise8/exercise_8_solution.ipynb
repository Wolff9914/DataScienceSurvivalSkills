# %% [markdown]
# # Exercise 8) Part 1: Image classification

# %%
from keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn

# %% [markdown]
# ## Loading the Fashion-MNIST dataset

# %%
# Load the dataset using Keras
(x_train,y_train),(x_test,y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 3s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
# Shape of training images?
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# Shape of training labels?
y_train.shape
# Out:
# (60000,)

# %% [markdown]
# ## Preprocessing

# %%
x_train.min(), x_train.max()
# Out:
# (0, 255)

# %%
# Scale values to [0, 1]
x_train = x_train/255.0
x_test = x_test/255.0

# %%
x_train.min(), x_train.max()
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## Let's have a look at the data

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# First training sample
idx = 0
img = x_train[idx]
label = y_train[idx]

# Plot image with class label


# Plot image with class label
plt.imshow(img, cmap="binary")
plt.title(f"{label}: {class_names[label]}")
plt.show()

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap="binary")
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ## Model evaluation 1) Training & validation set

# %% [markdown]
# <img src="https://sebastianraschka.com/images/blog/2016/model-evaluation-selection-part3/holdout-validation_01.png" width="1000" align="left">

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# Split into 80% training and 20% validation set
x_train,x_val,y_train,y_val = train_test_split(x_train,y_train,test_size=0.2,random_state=42)

print(x_train.shape)
print(x_val.shape)
# Out:
# (48000, 28, 28)
# (12000, 28, 28)

# %% [markdown]
# ## Building a Multi-Layer Perceptron (MLP)
# ![Structure-of-multilayer-perceptron-neural-network-396035256.png](data:image/png;base64,...)

# %%
import tensorflow as tf
from keras import layers

def build_model():
    # MLP with 2 hidden layers (256, 128 units) and "relu" activation function
    model = tf.keras.Sequential()
    model.add(layers.Flatten(input_shape=(28,28)))
    model.add(layers.Dense(256,activation="relu"))
    model.add(layers.Dense(128,activation="relu"))
    model.add(layers.Dense(10,activation="softmax"))
    return model










model = build_model()
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         200,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 235,146 (918.54 KB)
#  Trainable params: 235,146 (918.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras import optimizers

# Choose optimizer & loss function and compile the model
opt = optimizers.SGD(learning_rate=0.01)
model.compile(optimizer=opt,loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
# Train the model for 50 epochs
history = model.fit(x_train,y_train,epochs=20,validation_data=(x_val,y_val))
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6604 - loss: 1.0545 - val_accuracy: 0.8070 - val_loss: 0.5545
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8229 - loss: 0.5186 - val_accuracy: 0.8357 - val_loss: 0.4770
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8413 - loss: 0.4547 - val_accuracy: 0.8458 - val_loss: 0.4429
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8485 - loss: 0.4323 - val_accuracy: 0.8544 - val_loss: 0.4243
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8568 - loss: 0.4141 - val_accuracy: 0.8565 - val_loss: 0.4030
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8635 - loss: 0.3906 - val_accuracy: 0.8597 - val_loss: 0.3974
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8666 - loss: 0.3760 - val_accuracy: 0.8642 - val_loss: 0.3815
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8714 - loss: 0.3664 - val_accuracy: 0.8693 - val_loss: 0.3708
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8748 - loss: 0.3526 - val_accuracy: 0.8721 - val_loss: 0.3629
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8806 - loss: 0.3398 - val_accuracy: 0.8665 - val_loss: 0.3762
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8798 - loss: 0.3375 - val_accuracy: 0.8731 - val_loss: 0.3580
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8826 - loss: 0.3257 - val_accuracy: 0.8752 - val_loss: 0.3533
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8844 - loss: 0.3212 - val_accuracy: 0.8761 - val_loss: 0.3475
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8892 - loss: 0.3087 - val_accuracy: 0.8741 - val_loss: 0.3521
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8927 - loss: 0.2992 - val_accuracy: 0.8777 - val_loss: 0.3424
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8943 - loss: 0.2980 - val_accuracy: 0.8807 - val_loss: 0.3338
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8955 - loss: 0.2925 - val_accuracy: 0.8742 - val_loss: 0.3466
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8950 - loss: 0.2862 - val_accuracy: 0.8818 - val_loss: 0.3273
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8990 - loss: 0.2787 - val_accuracy: 0.8861 - val_loss: 0.3238
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8988 - loss: 0.2806 - val_accuracy: 0.8848 - val_loss: 0.3246

# %%
# Plot accuracy
plt.figure(figsize=(4, 3))
plt.plot(history.history["accuracy"], label="training accuracy")
plt.plot(history.history["val_accuracy"], label="validation accuracy")
plt.legend()
plt.xlabel("epochs")
plt.show()

# %%
# Plot loss
plt.figure(figsize=(4, 3))
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.legend()
plt.xlabel("epochs")
plt.show()

# %% [markdown]
# **How to interpret the loss curve?**
#
# <img src="https://miro.medium.com/v2/resize:fit:786/format:webp/1*lARssDbZVTvk4S-Dk1g-eA.png" width=500 align="left">

# %% [markdown]
# ## Check how well the model does on our test data

# %%
# Get predictions for test data
y_predicted = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# Get prediction for a test image
img = x_test[12]
pred = y_predicted[12]
true_class = y_test[12]

# %%
plt.imshow(img, cmap="binary")

# %%
print(class_names[true_class], true_class)
# Out:
# Sneaker 7

# %%
pred
# Out:
# array([1.6667755e-05, 3.3611625e-05, 6.5085733e-05, 3.0168211e-03,
#        1.5300851e-05, 8.1693828e-01, 6.1075912e-06, 1.6575801e-01,
#        1.4050249e-02, 9.9791410e-05], dtype=float32)

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br>

# %%
# Why does the prediction look like this? -> softmax activation, 10 classes
for i in range(10):
    print(f"{pred[i]:.2f} - {class_names[i]}")
# Out:
# 0.00 - T-shirt/top
# 0.00 - Trouser
# 0.00 - Pullover
# 0.00 - Dress
# 0.00 - Coat
# 0.82 - Sandal
# 0.00 - Shirt
# 0.17 - Sneaker
# 0.01 - Bag
# 0.00 - Ankle boot

# %%
# Highest value?
pred.max(

)
# Out:
# 0.8169383

# %%
# Which class has the highest prediction?
class_names[pred.argmax()]
# Out:
# 'Sandal'

# %%
# Turn all predictions into predicted classes (0, 1, 2 ... or 9)
predicted_classes = np.argmax(y_predicted,axis=-1)

# %%
plt.figure(figsize=(12, 12))
for i in range(25):

    # Get true class for current image
    true_class = class_names[y_test[i]]

    # Get prediction
    prediction = y_predicted[i]
    predicted_class = class_names[np.argmax(prediction)]

    text = f"{predicted_class} (true: {true_class})"

    color = "green" if predicted_class == true_class else "red"

    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap="binary")
    plt.xlabel(text, color=color)
plt.show()

# %%
# Get accuracy for test dataset
test_loss, test_acc = model.evaluate(x_test, y_test)
test_acc *= 100

print(f"Test accuracy: {test_acc:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8785 - loss: 0.3491
# Test accuracy: 87.69%

# %%
# Show confusion matrix for test dataset
conf_matrix = sklearn.metrics.confusion_matrix(y_test, predicted_classes)


sns.heatmap(conf_matrix, annot=True, fmt="d",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted class")
plt.ylabel("True class")
plt.show()

# %% [markdown]
# ## Model evaluation 2) k-fold cross-validation

# %% [markdown]
# <img src="https://sebastianraschka.com/images/blog/2016/model-evaluation-selection-part3/kfold.png" width="600" align="left">

# %%
(x, y), (x_test, y_test) = fashion_mnist.load_data()
x = x / 255.0
x_test = x_test / 255.0

# %%
# Set up 5-fold cross-validation
kfold = sklearn.model_selection.KFold(n_splits=5,shuffle= True)

accuracy_list = []
fold = 1

for train_idx, val_idx in kfold.split(x_train):

    # Training folds
    x_train = x[train_idx]
    y_train = y[train_idx]

    # Validation fold
    x_val = x[val_idx]
    y_val = y[val_idx]



    # MLP
    model = build_model()
    opt = optimizers.SGD(learning_rate=0.01)
    model.compile(optimizer=opt,loss="sparse_categorical_crossentropy",metrics=["accuracy"])
    # Train
    model.fit(x_train, y_train, epochs=20, batch_size=128, verbose=0)
    # Evaluate
    val_loss, val_acc = model.evaluate(x_val, y_val, verbose=0)

    print(f"Fold {fold}: Accuracy {val_acc:.4f}")
    accuracy_list.append(val_acc)
    fold += 1
# Out:
# Fold 1: Accuracy 0.8504
# Fold 2: Accuracy 0.8458
# Fold 3: Accuracy 0.8477
# Fold 4: Accuracy 0.8487
# Fold 5: Accuracy 0.8600

# %%
# Get average validation accuracy
mean_val_accuracy= np.mean(accuracy_list)*100
print(f"Mean validation accuracy (5-fold CV): {mean_val_accuracy:.2f} %")
# Out:
# Mean validation accuracy (5-fold CV): 85.05 %

# %% [markdown]
# <br><br><br>
#
#
# # Part 2: Image segmentation

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import Sequence
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# Function to load and preprocess images and masks
def load_data(image_dir, mask_dir, img_size=(128, 128)):
    images = []
    masks = []

    for i in range(100):  #  0 to 99
        img_path = os.path.join(image_dir, f"{i}.png")
        mask_path = os.path.join(mask_dir, f"{i}_seg.png")

        if os.path.exists(img_path) and os.path.exists(mask_path):
            # Load image and mask
            img = tf.keras.utils.load_img(img_path, color_mode="grayscale", target_size=img_size)
            mask = tf.keras.utils.load_img(mask_path, color_mode="grayscale", target_size=img_size)

            # Convert to numpy arrays and normalize
            img = np.array(img) / 255.0
            mask = np.array(mask) / 255.0

            # Expand dims for channel consistency
            images.append(np.expand_dims(img, axis=-1))
            masks.append(np.expand_dims(mask, axis=-1))

    return np.array(images), np.array(masks)

# Dataset paths
image_dir = "/content/Dataset/"  # Update with your directory
mask_dir = "/content/Dataset/"    # Update with your directory

# Load dataset
images, masks = load_data(image_dir, mask_dir)

# Train-test split
X_train, X_val, y_train, y_val = train_test_split(images, masks, test_size=0.2, random_state=42)

# %%
import matplotlib.pyplot as plt

# Plot training image with mask (glottis)
def show_image_and_mask(x, y):
    plt.subplot(1,2,1)
    plt.imshow(x[...,0], cmap='gray')
    plt.subplot(1,2,2)
    plt.imshow(y[...,0], cmap='gray')
    plt.show()


show_image_and_mask(X_train[0], y_train[0])

# %% [markdown]
# ## Build U-Net

# %% [markdown]
# **Original U-Net:**
#
# Ronneberger, O., Fischer, P., & Brox, T. (2015, October). U-net: Convolutional networks for biomedical image segmentation. In _International Conference on Medical image computing and computer-assisted intervention_ (pp. 234-241). Springer, Cham.
#
# <img align="left" src=https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png width=500>

# %%
# Simplified U-Net
# (2 encoder & decoder blocks, 16 initial filters)
from keras.layers import Conv2D, Input, MaxPool2D, UpSampling2D, Activation, BatchNormalization, Concatenate
from keras.models import Model
def conv_block(x, num_filters):
  # Convolutional layer with kernel size 3, padding "same"
  x = Conv2D(num_filters, 3, padding="same")(x)
  x = BatchNormalization()(x)
  x = Activation("relu")(x)

  # Convolutional layer with kernel size 3, padding "same"
  x = Conv2D(num_filters, 3, padding="same")(x)
  # BatchNormalization layer
  x=BatchNormalization()(x)
  # Activation function "relu"
  x = Activation("relu")(x)
  return x


def build_Unet(filters=16, num_classes=1):
    # Input layer
    inputs = Input(shape=(128, 128, 1))
    # Encoder
    e1 = conv_block(inputs,filters)
    p1 = MaxPool2D((2,2))(e1)
    e2 = conv_block(p1,filters*2)
    p2= MaxPool2D((2,2))(e2)

    # Bottleneck
    b1 = conv_block(p2,filters*16)

    # Decoder
    d1 = UpSampling2D()(b1)
    d1 = Concatenate(axis=3)([d1,e2])
    d1 = conv_block(d1,filters*8)

    d2 = UpSampling2D()(d1)
    d2 = Concatenate(axis=3)([d2,e1])
    d2 = conv_block(d2,filters*4)



    # Output layer
    outputs = Conv2D(filters = num_classes,kernel_size=1,padding="same",activation="sigmoid")(d2)

    return Model(inputs, outputs)

# %% [markdown]
# ## Train U-Net
#
# A great library for image segmentation: https://segmentation-models.readthedocs.io/

# %%
# Build U-Net model
model = build_Unet()
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=16,
    epochs=50
)
# Out:
# Epoch 1/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 30s 852ms/step - accuracy: 0.8018 - loss: 0.5329 - val_accuracy: 0.9945 - val_loss: 0.6624
# Epoch 2/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 106ms/step - accuracy: 0.9929 - loss: 0.1800 - val_accuracy: 0.2568 - val_loss: 0.7368
# Epoch 3/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9950 - loss: 0.1216 - val_accuracy: 0.0706 - val_loss: 0.9156
# Epoch 4/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9944 - loss: 0.1029 - val_accuracy: 0.0470 - val_loss: 0.9444
# Epoch 5/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9952 - loss: 0.0840 - val_accuracy: 0.0633 - val_loss: 0.8098
# Epoch 6/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.9945 - loss: 0.0785 - val_accuracy: 0.7772 - val_loss: 0.6332
# Epoch 7/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.9945 - loss: 0.0691 - val_accuracy: 0.9943 - val_loss: 0.5200
# Epoch 8/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.9955 - loss: 0.0604 - val_accuracy: 0.9945 - val_loss: 0.4070
# Epoch 9/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9951 - loss: 0.0553 - val_accuracy: 0.9945 - val_loss: 0.3153
# Epoch 10/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9957 - loss: 0.0487 - val_accuracy: 0.9945 - val_loss: 0.2498
# Epoch 11/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9969 - loss: 0.0443 - val_accuracy: 0.9945 - val_loss: 0.2073
# Epoch 12/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9976 - loss: 0.0411 - val_accuracy: 0.9945 - val_loss: 0.1868
# Epoch 13/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9976 - loss: 0.0399 - val_accuracy: 0.9945 - val_loss: 0.1663
# Epoch 14/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9971 - loss: 0.0376 - val_accuracy: 0.9945 - val_loss: 0.1458
# Epoch 15/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9981 - loss: 0.0337 - val_accuracy: 0.9945 - val_loss: 0.1286
# Epoch 16/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.9976 - loss: 0.0311 - val_accuracy: 0.9945 - val_loss: 0.1146
# Epoch 17/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.9974 - loss: 0.0301 - val_accuracy: 0.9945 - val_loss: 0.1056
# Epoch 18/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.9978 - loss: 0.0274 - val_accuracy: 0.9945 - val_loss: 0.0952
# Epoch 19/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.9983 - loss: 0.0250 - val_accuracy: 0.9945 - val_loss: 0.0867
# Epoch 20/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9983 - loss: 0.0236 - val_accuracy: 0.9945 - val_loss: 0.0784
# Epoch 21/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9983 - loss: 0.0227 - val_accuracy: 0.9945 - val_loss: 0.0700
# Epoch 22/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9980 - loss: 0.0218 - val_accuracy: 0.9945 - val_loss: 0.0641
# Epoch 23/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9982 - loss: 0.0208 - val_accuracy: 0.9945 - val_loss: 0.0601
# Epoch 24/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9984 - loss: 0.0198 - val_accuracy: 0.9945 - val_loss: 0.0579
# Epoch 25/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9981 - loss: 0.0200 - val_accuracy: 0.9945 - val_loss: 0.0551
# Epoch 26/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9985 - loss: 0.0182 - val_accuracy: 0.9945 - val_loss: 0.0520
# Epoch 27/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9984 - loss: 0.0175 - val_accuracy: 0.9945 - val_loss: 0.0502
# Epoch 28/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9984 - loss: 0.0186 - val_accuracy: 0.9945 - val_loss: 0.0481
# Epoch 29/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9985 - loss: 0.0166 - val_accuracy: 0.9945 - val_loss: 0.0464
# Epoch 30/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9988 - loss: 0.0154 - val_accuracy: 0.9945 - val_loss: 0.0460
# Epoch 31/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9987 - loss: 0.0152 - val_accuracy: 0.9945 - val_loss: 0.0459
# Epoch 32/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.9987 - loss: 0.0141 - val_accuracy: 0.9945 - val_loss: 0.0449
# Epoch 33/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9986 - loss: 0.0143 - val_accuracy: 0.9945 - val_loss: 0.0438
# Epoch 34/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.9986 - loss: 0.0138 - val_accuracy: 0.9945 - val_loss: 0.0426
# Epoch 35/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9985 - loss: 0.0138 - val_accuracy: 0.9945 - val_loss: 0.0417
# Epoch 36/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9989 - loss: 0.0127 - val_accuracy: 0.9945 - val_loss: 0.0398
# Epoch 37/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9987 - loss: 0.0126 - val_accuracy: 0.9945 - val_loss: 0.0386
# Epoch 38/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.9988 - loss: 0.0117 - val_accuracy: 0.9945 - val_loss: 0.0381
# Epoch 39/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9988 - loss: 0.0112 - val_accuracy: 0.9945 - val_loss: 0.0374
# Epoch 40/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.9988 - loss: 0.0111 - val_accuracy: 0.9945 - val_loss: 0.0372
# Epoch 41/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.9989 - loss: 0.0106 - val_accuracy: 0.9945 - val_loss: 0.0368
# Epoch 42/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.9984 - loss: 0.0114 - val_accuracy: 0.9945 - val_loss: 0.0362
# Epoch 43/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9987 - loss: 0.0107 - val_accuracy: 0.9945 - val_loss: 0.0359
# Epoch 44/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9984 - loss: 0.0112 - val_accuracy: 0.9945 - val_loss: 0.0353
# Epoch 45/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9989 - loss: 0.0100 - val_accuracy: 0.9945 - val_loss: 0.0351
# Epoch 46/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9989 - loss: 0.0096 - val_accuracy: 0.9945 - val_loss: 0.0346
# Epoch 47/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.9990 - loss: 0.0091 - val_accuracy: 0.9945 - val_loss: 0.0346
# Epoch 48/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9988 - loss: 0.0092 - val_accuracy: 0.9945 - val_loss: 0.0339
# Epoch 49/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9989 - loss: 0.0091 - val_accuracy: 0.9945 - val_loss: 0.0340
# Epoch 50/50
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9983 - loss: 0.0105 - val_accuracy: 0.9945 - val_loss: 0.0332

# %%
def plot_training_history(history):
    plt.figure(figsize=(12, 4))

    # Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()


plot_training_history(history)

# %%
def visualize_predictions(model, X, y):
    predictions = model.predict(X[:5])
    plt.figure(figsize=(15, 10))
    for i in range(5):
        plt.subplot(5, 3, i * 3 + 1)
        plt.imshow(X[i].squeeze(), cmap='gray')
        plt.title("Image")

        plt.subplot(5, 3, i * 3 + 2)
        plt.imshow(y[i].squeeze(), cmap='gray')
        plt.title("Ground Truth")

        plt.subplot(5, 3, i * 3 + 3)
        plt.imshow(predictions[i].squeeze(), cmap='gray')
        plt.title("Prediction")

    plt.tight_layout()
    plt.show()

visualize_predictions(model, X_val, y_val)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %% [markdown]
# ##Big Unet trained on big Dataset

# %% [markdown]
# ![Unbenannt.png](data:image/png;base64,...)

# %% [markdown]
# ![Unbenannt-1.png](data:image/png;base64,...)
